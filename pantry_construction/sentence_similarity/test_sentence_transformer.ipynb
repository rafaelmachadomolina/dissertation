# %% [markdown]
# # Ingredient match experiment
#
# This notebook was created to experiment with sentence transformers to connect Kafoodle taxonomy with the ingredient database

# %%
### Import packages

import os
import time
from datetime import datetime, timezone
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from sqlalchemy import create_engine

from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

import warnings
warnings.filterwarnings('ignore')

# %%
### Download models from sentence transformer package

model = SentenceTransformer('paraphrase-mpnet-base-v2')

# %%
### Define constants

EXCEL_PATH = 'excel/'
PARQUET_PATH = 'parquet/'
CSV_PATH = 'csv/'
RANDOM_SEED = 888

PLOT_SETUP = {'title': 18,
              'subtitle': 16,
              'label': 14,
              'tick': 12,
              'legend': 14}

# %%
### Define DB connection

DB_NAME_STAGE = os.environ['DB_NAME_STAGE']
DB_HOST_STAGE = os.environ['DB_HOST_STAGE']
DB_PORT_STAGE = os.environ['DB_PORT_STAGE']
DB_USERNAME_STAGE = os.environ['DB_USERNAME_STAGE']
DB_PASSWORD_STAGE = os.environ['DB_PASSWORD_STAGE']

TABLE_NAME_TAXONOMY = 'kp_ingredient_taxonomy'
TABLE_NAME_INGREDIENTS = 'kp_ingredients_base_pantry'

STRING_CONN = f'mysql+pymysql://{DB_USERNAME_STAGE}:{DB_PASSWORD_STAGE}@{DB_HOST_STAGE}:{DB_PORT_STAGE}/{DB_NAME_STAGE}'

# %%
### Define functions

def _get_key():
    '''
    This function returns a string with the current timestamp.

    Returns
    -------
    key : string with current timestamp
    '''
    dt_now = datetime.now(tz=timezone.utc)
    KEY = (
        dt_now.strftime("%Y-%m-%d")
        + "-"
        + dt_now.strftime("%H")
        + "-"
        + dt_now.strftime("%M")
        + "_"
    )
    return KEY;

def extract_data_sql(tableName, string_conn):
    '''
    Retrieves a given table in the database and stores it in a pandas DataFrame

    Parameters
    ----------
    tableName : string
        Name of table in the database
    string_conn : string
        String containing connection protocol to database.

    Returns
    -------
    DataFrame
        Dataframe containing the table.

    '''
    
    sqlEngine = create_engine(string_conn)
    dbConnection = sqlEngine.connect()
    
    try:
        df = pd.read_sql_table(tableName, dbConnection)
        print('Query successfully executed')
        return df;

    except Exception as ex:   
        print(ex)

    finally:
        dbConnection.close()
 
# Get vectorized standardised taxonomy
def get_vectorised_taxonomy(df, vec_model):
    
    dict_vector = {}
    
    list_categories = df['category_id'].unique()
    
    for CAT in list_categories:
        df_filtered = df[df['category_id'] == CAT].reset_index(drop = True) # Drop index to avoid error in encoding
        list_names = df_filtered['ingredient_name'].tolist()
        array_vectors = model.encode(df_filtered['ingredient_name'])
        
        dict_vector[CAT] = {'ingredient_names': list_names,
                           'vectorized_representation': array_vectors}
    
    return dict_vector;

# Match taxonomy with vectorised ingredients
def match_ingredients(df, vec_model, dict_vector_taxonomy):

    DF_COLS = df.columns.tolist()
    DF_COLS.extend(['matched_ingredient', 'matched_score'])

    return_df = pd.DataFrame(columns = DF_COLS)

    for CAT in dict_vector_taxonomy.keys():
    # for CAT in [101]:
        df_filtered = df[df['category_id'] == CAT].reset_index(drop = True) # Drop index to avoid error in encoding
        list_names = dict_vector_taxonomy[CAT]['ingredient_names']
        taxonomy_scores = dict_vector_taxonomy[CAT]['vectorized_representation']

        if len(df_filtered) == 0: # Continue if no ingredient is found from this category
            continue

        # Enconde ingredients
        encoded_ingredients = vec_model.encode(df_filtered['ingredient_name'])

        # Calculate cosine similarity
        cosine_matrix = cosine_similarity(encoded_ingredients, taxonomy_scores)

        # Get best match
        best_score_idx = np.argmax(cosine_matrix, axis = 1)

        # Assign ingredient and score to df
        matched_ingredient = [list_names[i] for i in best_score_idx]
        matched_score = [cosine_matrix[i][j] for i, j in enumerate(best_score_idx)]

        df_filtered['matched_ingredient'] = matched_ingredient
        df_filtered['matched_score'] = matched_score

        # Append to final df
        return_df = pd.concat([return_df, df_filtered])

    # Reset index
    return_df.reset_index(drop = True, inplace = True)
    
    return return_df;

# Must separate the actual cosine calculation from the categories. In that way, it can be timed for efficiency

# %%
### Read data

df_taxonomy = extract_data_sql(TABLE_NAME_TAXONOMY, STRING_CONN)
df_ingredients = extract_data_sql(TABLE_NAME_INGREDIENTS, STRING_CONN)
# Out:
# Query successfully executed
# Query successfully executed

# %%
### Estimate vectorised taxonomy 

dict_vectorised_taxonomy = get_vectorised_taxonomy(df_taxonomy, model)
dict_vectorised_taxonomy
# Out:
# {101: {'ingredient_names': ['crab',
#    'lobsters',
#    'gambas',
#    'prawns',
#    'shrimp-skewers',
#    'jumbo-shrimps',
#    'shrimps-tails',
#    'spider-crab',
#    'spiny-lobsters',
#    'anchovy',
#    'anglers',
#    'bass',
#    'breams',
#    'cod-fillets',
#    'cod-livers',
#    'canned-herrings',
#    'pacific-herring',
#    'pickled-herring',
#    'smoked-herrings',
#    'mackerel-fillets-in-escabeche',
#    'mackerel-fillets-in-mustard-sauce',
#    'mackerel-fillets-in-oil',
#    'mackerel-fillets-in-white-wine-and-herbs',
#    'mackerels-fillets-with-olives-and-lemon',
#    'mackerels-fillets-with-tomato-and-basilisk',
#    'plain-mackerels-fillets',
#    'tinned-mackerels',
#    'pollock-fillets',
#    'canned-salmons',
#    'salmon-fillets',
#    'salmons-from-farming',
#    'smoked-salmons-from-farming',
#    'wild-smoked-salmons',
#    'sardines-in-oil-and-lemon',
#    'sardines-in-sunflower-oil',
#    'sardines-in-tomato-sauce',
#    'sardines-without-oil',
#    'smoked-trouts',
#    'atlantic-bluefin-tunas',
#    'bigeye-tunas',
#    'canned-tunas',
#    'longtail-tuna',
#    'smoked-tunas',
#    'tropical-tunas',
#    'tuna-fillets',
#    'whole-tunas',
#    'jellyfish',
#    'calamari',
#    'mussels',
#    'octopus',
#    'oysters',
#    'scallop',
#    'haddock'],
#   'vectorized_representation': array([[ 0.01381582,  0.19217348, -0.09830612, ..., -0.02116003,
#            0.04503526, -0.04452063],
#          [-0.07093236,  0.18129122, -0.07761448, ...,  0.02746147,
#            0.04385448, -0.0615888 ],
#          [ 0.0801932 ,  0.14855143, -0.02829709, ...,  0.12620434,
#           -0.02801909,  0.01072241],
#          ...,
#          [-0.07899123,  0.3077635 , -0.12905504, ..., -0.14878811,
#            0.08513623, -0.11311483],
#          [-0.08769457, -0.12379725,  0.01258977, ..., -0.015355  ,
#            0.18591142, -0.00079865],
#          [-0.06835239, -0.04819282, -0.0826977 , ..., -0.02538181,
#           -0.12787795, -0.11041714]], dtype=float32)},
#  102: {'ingredient_names': ['ground-beef',
#    'beef-steaks',
#    'beef-jerkies',
#    'lamb',
#    'veal-meat',
#    'dromedary',
#    'european-moose-meat',
#    'frog',
#    'ants',
#    'ostrich',
#    'smoked-back-bacon',
#    'smoked-rindless-back-bacon-rashers',
#    'unsmoked-back-bacon',
#    'unsmoked-rindless-back-bacon-rashers',
#    'rindless-short-cut-bacon',
#    'sliced-bacon',
#    'smoked-bacon-lardons',
#    'pig-heart',
#    'pork-belly',
#    'pork-ribs',
#    'pork-tongue',
#    'capon',
#    'chicken-breasts',
#    'chicken-thighs',
#    'chicken-wings',
#    'duck-breast',
#    'duck-legs',
#    'geese',
#    'pigeon',
#    'turkey-breast',
#    'turkey-thighs',
#    'rabbit-meat',
#    'reindeer-meat',
#    'roe-deer-meat',
#    'canned-snails',
#    'fresh-snails',
#    'wapiti-elk-meat',
#    'zebra',
#    'pork-loin',
#    'pork-shoulder',
#    'pork-leg'],
#   'vectorized_representation': array([[-0.11962239,  0.04805986,  0.05383101, ...,  0.06508283,
#            0.03154973, -0.00828844],
#          [-0.02246426,  0.12552433, -0.00780681, ...,  0.14168091,
#            0.06522863, -0.02034693],
#          [-0.07941342,  0.16306059, -0.02652398, ...,  0.17988302,
#            0.04313771, -0.07646061],
#          ...,
#          [-0.06778804,  0.17206931,  0.03142062, ...,  0.13041888,
#            0.0649608 , -0.10512713],
#          [-0.09283707,  0.22724395, -0.00731266, ...,  0.15879372,
#            0.03973508, -0.06158462],
#          [-0.09731577,  0.382507  , -0.013174  , ...,  0.20397525,
#           -0.00352296, -0.07628854]], dtype=float32)},
#  103: {'ingredient_names': ['canned-artichokes',
#    'canned-green-asparagus',
#    'canned-white-asparagus',
#    'canned-beet',
#    'canned-brussels-sprouts',
#    'canned-cabbage',
#    'canned-carrots',
#    'canned-celery',
#    'canned-chards',
#    'canned-corn',
#    'canned-hearts-of-palm',
#    'canned-leeks',
#    'canned-peppers',
#    'canned-potatoes',
#    'canned-salsifis',
#    'canned-spinachs',
#    'canned-sweet-corn',
#    'pickled-aubergines',
#    'pickled-beets',
#    'pickled-carrots',
#    'gherkins',
#    'pickled-garlic',
#    'pickled-onions',
#    'pickled-peppers',
#    'dried-tomatoes-in-oil',
#    'natural-dried-tomatoes',
#    'aubergines',
#    'broad-beans',
#    'broccoli',
#    'brussels-sprouts',
#    'carrots',
#    'cucumbers',
#    'black-garlic',
#    'green-garlic',
#    'white-garlic',
#    'broad-green-beans',
#    'flat-green-beans',
#    'green-pigeon-peas',
#    'cabbage',
#    'cauliflower',
#    'endives',
#    'garden-cress',
#    'red-cabbage',
#    'rocket',
#    'romanesco',
#    'spinachs',
#    'watercress',
#    'golden-onion',
#    'onion-sprouts',
#    'red-onion',
#    'scallions',
#    'shallots',
#    'spring-onion',
#    'white-onion',
#    'agata-potatoes',
#    'charlotte-potatoes',
#    'sweet-potatoes',
#    'butternut-squashes',
#    'spaghetti-squashes',
#    'daikon-radishes',
#    'red-radishes',
#    'green-bell-peppers',
#    'red-bell-peppers',
#    'yellow-bell-peppers',
#    'strained-tomatoes',
#    'tomato-pastes',
#    'tomato-purees',
#    'cherry-tomatoes',
#    'pumpkin-tomatoes',
#    'tomatoe',
#    'turnip',
#    'artichoke',
#    'green-asparagus',
#    'miniature-asparagus',
#    'purple-asparagus',
#    'white-asparagus',
#    'wild-asparagus',
#    'cardoons',
#    'celery',
#    'fennel-bulbs',
#    'leeks',
#    'rhubarbs',
#    'zucchini',
#    'frozen-artichoke',
#    'frozen-green-asparagus',
#    'frozen-white-asparagus',
#    'frozen-aubergines',
#    'frozen-broccoli-florets',
#    'frozen-brussels-sprouts',
#    'frozen-butter-beans',
#    'frozen-cardoons',
#    'frozen-baby-carrots',
#    'frozen-chopped-carrots',
#    'frozen-chard-leaves',
#    'frozen-chopped-chards',
#    'frozen-chopped-garlic',
#    'frozen-chopped-onions',
#    'frozen-fresh-broad-beans',
#    'frozen-green-beans',
#    'frozen-green-garlic',
#    'frozen-green-peas',
#    'frozen-leeks',
#    'frozen-green-peppers',
#    'frozen-red-peppers',
#    'frozen-yellow-peppers',
#    'frozen-potatoes',
#    'frozen-pumpkins',
#    'frozen-red-cabbage',
#    'frozen-salsify',
#    'frozen-turnips',
#    'frozen-zucchini',
#    'yukon-gold-potatoes',
#    'maris-piper-potatoes',
#    'king-edward-potatoes',
#    'russet-potatoes',
#    'jersey-potatoes',
#    'cara-potatoes',
#    'beet',
#    'leaf-lettuces',
#    'romaine-lettuces',
#    'iceberg-lettuces',
#    'boston-lettuces',
#    'bibb-lettuces',
#    'kale',
#    'oak-leaf-lettuces',
#    'radicchio'],
#   'vectorized_representation': array([[-7.42384419e-02,  1.58086330e-01, -1.39119014e-01, ...,
#           -3.83433029e-02, -1.08183071e-01, -1.12354979e-01],
#          [-3.19195651e-02, -4.49032895e-02, -2.34346688e-02, ...,
#           -1.06861591e-01, -1.24566704e-01, -7.85598755e-02],
#          [-2.95805726e-02,  7.39971250e-02, -3.24841850e-02, ...,
#           -1.19266883e-01, -9.01390016e-02, -8.36284384e-02],
#          ...,
#          [ 3.72100100e-02, -3.01828325e-01, -4.55545746e-02, ...,
#            7.14713475e-04, -2.89225057e-02, -4.18047942e-02],
#          [-6.48931414e-02, -1.40787467e-01, -8.00358364e-04, ...,
#           -6.01204485e-02,  4.06912193e-02, -7.43353963e-02],
#          [-5.18054962e-02, -7.42854550e-02, -1.99291520e-02, ...,
#           -2.99797840e-02,  5.18444665e-02,  1.21979414e-04]], dtype=float32)},
#  105: {'ingredient_names': ['almond-meal',
#    'almond-milks',
#    'chestnut-milks',
#    'hazelnut-milks',
#    'macadamia-nut-milks',
#    'walnut-milks',
#    'almonds',
#    'brazil-nuts',
#    'chestnuts',
#    'hazelnuts',
#    'macadamia-nuts',
#    'peanuts',
#    'pecan-nuts',
#    'pine-nuts',
#    'pistachios',
#    'shelled-almonds',
#    'shelled-brazil-nuts',
#    'shelled-chestnuts',
#    'shelled-hazelnuts',
#    'shelled-macadamia-nuts',
#    'shelled-pecan-nuts',
#    'shelled-pine-nuts',
#    'shelled-pistachios',
#    'shelled-walnuts',
#    'walnuts',
#    'fenugreek-seeds',
#    'mustard-seeds',
#    'papaver-seeds',
#    'sunflower-seeds'],
#   'vectorized_representation': array([[-1.29290894e-01, -4.98773009e-01,  2.76251379e-02, ...,
#            3.60276699e-02, -7.92969242e-02,  8.80620163e-03],
#          [-7.76349604e-02, -2.88495511e-01,  4.23580222e-02, ...,
#           -4.05407511e-04, -8.47432588e-04,  5.21908067e-02],
#          [-4.57830690e-02,  2.43548974e-02,  3.43731046e-02, ...,
#            7.87713155e-02,  7.81541094e-05, -9.00727417e-03],
#          ...,
#          [-4.32986543e-02, -1.11078024e-01, -2.70860596e-03, ...,
#            2.15770096e-01, -7.35700652e-02,  3.19047682e-02],
#          [-3.17749865e-02, -3.52569036e-02,  7.00816959e-02, ...,
#            1.03169270e-01, -2.79266331e-02,  9.88354161e-03],
#          [-8.57679024e-02, -2.08280385e-02,  8.78857449e-03, ...,
#            4.89478409e-02,  5.30685596e-02,  2.39736512e-02]], dtype=float32)},
#  107: {'ingredient_names': ['brie',
#    'camembert',
#    'cabecous',
#    'cancoillottes',
#    'cheeses-from-corsica',
#    'epoisses-de-bourgogne',
#    'french-gruyeres',
#    'munsters',
#    'pont-l-eveque',
#    'saint-felicien-cheese',
#    'valencay-cheese',
#    'feta',
#    'halloumi',
#    'gorgonzolas',
#    'grana-padano',
#    'mascarpone',
#    'parmigiano-reggiano',
#    'appenzeller-cheese',
#    'swiss-gruyeres',
#    'edam',
#    'goudas-with-cumin',
#    'old-goudas',
#    'orange-goudas',
#    'red-goudas',
#    'white-gouda',
#    'yellow-gouda',
#    'young-gouda',
#    'maasdam',
#    'applewood-cheese',
#    'ashdown-foresters',
#    'beacon-fell-traditional-lancashire-cheese',
#    'beenleigh-blue-cheese',
#    'bowland-cheese',
#    'brighton-blue',
#    'buxton-blue',
#    'cathedral-city-cheddar',
#    'cheddar-slices',
#    'extra-mature-cheddar',
#    'mature-cheddar',
#    'mild-cheddar',
#    'cheshire-cheese',
#    'chevington-cheese',
#    'coquetdale-cheese',
#    'cornish-yarg',
#    'croglin',
#    'derby-cheese',
#    'dorset-blue-vinney',
#    'dorset-drum',
#    'dovedale-cheese',
#    'duddleswell-cheese',
#    'fine-fettle-yorkshire',
#    'five-counties-cheese',
#    'gloucester-cheese',
#    'harbourne-blue',
#    'lancashire-cheese',
#    'lincolnshire-poacher-cheese',
#    'little-derby',
#    'lymeswold-cheese',
#    'newport-1665',
#    'norbury-blue',
#    'parlick-fell-cheese',
#    'pilgrims-choice',
#    'red-leicester',
#    'red-windsor',
#    'sage-derby',
#    'shropshire-blue',
#    'stichelton',
#    'stilton-cheese',
#    'stinking-bishop-cheese',
#    'suffolk-gold-cheese',
#    'sussex-slipcote',
#    'swaledale-cheese',
#    'the-cheese-shop',
#    'waterloo-cheese',
#    'wensleydale-cheese',
#    'wrekin-white',
#    'coleraine-cheddar',
#    'bonchester',
#    'caboc',
#    'crowdie',
#    'dunlop',
#    'isle-of-mull-cheddar',
#    'lanark-blue',
#    'caerphilly',
#    'pantysgawn',
#    'tintern',
#    'y-fenni',
#    'condensed-milks',
#    'buttermilk',
#    'sour-cream',
#    'uht-cream',
#    'barn-chicken-eggs',
#    'cage-chicken-eggs',
#    'free-range-chicken-eggs',
#    'duck-eggs',
#    'emu-eggs',
#    'fresh-eggs',
#    'goose-eggs',
#    'guineafowl-eggs',
#    'gull-eggs',
#    'ostrich-eggs',
#    'pheasant-eggs',
#    'quail-eggs',
#    'cow-milks',
#    'goat-milks',
#    'lactose-free-milk',
#    'mountain-milks',
#    'raw-milks',
#    'semi-skimmed-milks',
#    'sheep-milks',
#    'skimmed-milks',
#    'whole-milks',
#    'whey-powder',
#    'caramel-yogurts',
#    'chocolate-yogurts',
#    'cow-milk-yogurt',
#    'flavoured-yogurts',
#    'goat-milk-yogurts',
#    'greek-yogurts',
#    'honey-yogurts',
#    'lactose-free-yogurts',
#    'low-fat-yogurts',
#    'mixed-yogurts',
#    'plain-yogurts',
#    'sheep-milk-yogurts',
#    'fruit-stirred-yogurts',
#    'plain-stirred-yogurts',
#    'sweetened-yogurts',
#    'vanilla-yogurt',
#    'whole-milk-yogurts',
#    'yogurts-with-cereals',
#    'unsalted-butter',
#    'salted-butter',
#    'whipping-cream'],
#   'vectorized_representation': array([[-0.15066889, -0.23066555,  0.01767126, ..., -0.05710397,
#            0.15629062, -0.02247802],
#          [-0.09105977, -0.0122231 ,  0.01360788, ..., -0.13579378,
#            0.06845774, -0.01297431],
#          [-0.25235176, -0.04352351, -0.11023612, ..., -0.0894722 ,
#            0.0419587 , -0.13432693],
#          ...,
#          [-0.074848  , -0.09706319, -0.0117264 , ...,  0.06583755,
#           -0.2096661 ,  0.0755254 ],
#          [-0.03501463, -0.38552034, -0.09929206, ...,  0.12305864,
#           -0.20850872,  0.08879119],
#          [-0.01428037, -0.19278857,  0.00313769, ..., -0.00926907,
#            0.02257718,  0.00959477]], dtype=float32)},
#  108: {'ingredient_names': ['canned-pineapples',
#    'apricots-in-syrup',
#    'canned-mixed-fruit-in-syrup',
#    'cherries-in-syrup',
#    'grapefruits-in-syrup',
#    'lychees-in-syrup',
#    'mangoes-in-syrup',
#    'peaches-in-syrup',
#    'pears-in-syrup',
#    'pineapple-in-syrup',
#    'dried-apples',
#    'dried-apricots',
#    'dried-bananas',
#    'dried-bilberries',
#    'dried-coconut-chips',
#    'dried-coconut-flour',
#    'dried-cranberries',
#    'dried-figs',
#    'dried-goji',
#    'dried-golden-berries',
#    'dried-mangoes',
#    'dried-mixed-fruits',
#    'dried-papayas',
#    'dried-peaches',
#    'dried-pineapple',
#    'dried-strawberries',
#    'grated-coconut',
#    'raisins',
#    'canada-reinettes-apples',
#    'granny-smith-apples',
#    'red-delicious-apples',
#    'russet-apples',
#    'fuji-apples',
#    'gala-apples',
#    'golden-delicious-apples',
#    'apricots',
#    'bilberries',
#    'blackberries',
#    'blackthorns',
#    'blueberries',
#    'cranberries',
#    'elderberries',
#    'lingonberries',
#    'raspberries',
#    'redcurrants',
#    'strawberries',
#    'cherries',
#    'grapefruits',
#    'lemons',
#    'limes',
#    'clementines',
#    'tangerines',
#    'oranges',
#    'pomelos',
#    'pitted-dates',
#    'whole-dates',
#    'figs',
#    'golden-berries',
#    'black-grapes',
#    'green-grapes',
#    'kakis',
#    'kiwi',
#    'medlars',
#    'branco-melons',
#    'canary-melons',
#    'charentais-melons',
#    'galia-melons',
#    'honeydew-melons',
#    'piel-de-sapo-melons',
#    'rochet-melons',
#    'tendral-melons',
#    'watermelon',
#    'nectarines',
#    'platerines',
#    'pears',
#    'pitayas',
#    'plums',
#    'pomegranates',
#    'quinces',
#    'avocados',
#    'bananas',
#    'chirimuyas',
#    'coconuts',
#    'guavas',
#    'lychees',
#    'mangoes',
#    'papayas',
#    'passion-fruits',
#    'pineapple',
#    'frozen-blackberries',
#    'frozen-blueberries',
#    'frozen-mixed-berries',
#    'frozen-raspberries',
#    'frozen-redcurrants',
#    'frozen-strawberries',
#    'frozen-citrus',
#    'frozen-pomegranates',
#    'frozen-avocados',
#    'frozen-pineapples',
#    'apple-pastes',
#    'guava-pastes',
#    'multifruit-pastes',
#    'peach-pastes',
#    'plum-pastes',
#    'quince-cheeses',
#    'fresh-fruit-salad',
#    'fruit-salads-in-syrup',
#    'black-chopped-olives',
#    'black-pitted-olives',
#    'whole-black-olives',
#    'green-chopped-olives',
#    'green-olives-in-brine',
#    'green-pitted-olives',
#    'whole-green-olives'],
#   'vectorized_representation': array([[ 5.0499473e-02,  1.7264366e-01, -3.2618869e-02, ...,
#           -7.9972088e-02, -6.6409804e-02,  1.6217681e-02],
#          [-5.7665493e-02, -5.0487059e-01, -2.2840852e-02, ...,
#            1.2944828e-01, -5.2091990e-02,  7.3544034e-03],
#          [ 4.4827156e-02, -3.7656334e-01, -2.6175547e-02, ...,
#           -1.0959692e-01, -5.4587066e-02, -8.4233889e-03],
#          ...,
#          [-1.0220612e-01, -2.9839495e-01,  6.5717641e-03, ...,
#           -1.1695669e-03, -8.1909485e-02,  6.2873334e-02],
#          [-4.9521837e-02, -2.2236809e-01, -7.6676290e-03, ...,
#            1.5873328e-02, -4.4339385e-02,  5.0211442e-04],
#          [-1.7215177e-02, -2.6287106e-01,  1.9433621e-02, ...,
#           -2.1604611e-02, -6.9385678e-02, -3.2627352e-02]], dtype=float32)},
#  109: {'ingredient_names': ['canned-broad-beans',
#    'canned-chickpeas',
#    'canned-flageolet-beans',
#    'canned-kidney-common-beans',
#    'canned-white-common-beans',
#    'canned-flat-green-beans',
#    'canned-green-pigeon-peas',
#    'canned-lentils',
#    'canned-peas',
#    'canned-peas-and-carrots',
#    'canned-scarlet-runner-beans',
#    'frozen-chickpeas',
#    'frozen-common-beans',
#    'frozen-lima-beans',
#    'chickpeas-flour',
#    'fresh-broad-flour',
#    'green-bean-flour',
#    'lentil-flour',
#    'lupin-bean-flour',
#    'soybean-flour',
#    'sweetened-natural-soy-milks',
#    'unsweetened-natural-soy-milks',
#    'fresh-broad-green-beans',
#    'fresh-flat-green-beans',
#    'fresh-green-pigeon-peas',
#    'green-peas',
#    'alfalfa-seeds',
#    'azuki-beans',
#    'bambara-groundnuts',
#    'black-eyed-peas',
#    'black-grams',
#    'butter-beans',
#    'chickpeas',
#    'black-beans',
#    'canela-beans',
#    'pinto-beans',
#    'red-beans',
#    'white-beans',
#    'cowpeas',
#    'hyacinth-beans',
#    'black-lentils',
#    'blonde-lentils',
#    'brown-lentils',
#    'green-lentils',
#    'red-lentils',
#    'lupin-beans',
#    'mat-beans',
#    'mung-beans',
#    'peas',
#    'pigeon-peas',
#    'rice-beans',
#    'scarlet-runner-beans',
#    'sword-beans',
#    'tepary-beans',
#    'velvet-beans',
#    'winged-beans',
#    'soy',
#    'dry-egg-pastas',
#    'dry-gluten-free-pastas',
#    'linguine',
#    'orecchiette',
#    'spaghetti',
#    'fettuccine',
#    'pappardelle',
#    'casarecce',
#    'penne',
#    'fusilli',
#    'bucatini',
#    'conchiglie',
#    'farfalle',
#    'fideo',
#    'orzo',
#    'rigatoni',
#    'tagliatelle',
#    'egg-noodles',
#    'udon',
#    'soba',
#    'ramen',
#    'yakisoba',
#    'arborio-rice',
#    'basmati-rice',
#    'black-rice',
#    'bomba-rice',
#    'brown-rice',
#    'jasmine-rice',
#    'long-grain-white-rice',
#    'sticky-rice',
#    'sushi-rice'],
#   'vectorized_representation': array([[-4.38444354e-02, -2.47478515e-01, -7.45870024e-02, ...,
#            2.55382098e-02, -1.16564453e-01, -3.93241867e-02],
#          [-8.16546753e-02,  5.48364855e-02, -1.03944376e-01, ...,
#           -4.93796840e-02, -1.13649249e-01, -1.05176903e-01],
#          [-4.92023081e-02, -5.01305908e-02, -1.23732582e-01, ...,
#            3.58848423e-02,  7.50176311e-02, -5.52742034e-02],
#          ...,
#          [-5.97438216e-02,  4.35437672e-02, -4.48104888e-02, ...,
#           -9.19401646e-05, -1.65314436e-01, -4.51247618e-02],
#          [ 1.42869845e-01, -3.70856762e-01, -1.14698872e-01, ...,
#            1.01415217e-02, -4.01630141e-02, -5.03759086e-03],
#          [ 1.75550759e-01, -1.56756658e-02, -8.06607231e-02, ...,
#            6.73072180e-03,  1.46918846e-02, -8.41407105e-02]], dtype=float32)},
#  110: {'ingredient_names': ['cocoa-butter',
#    'coconut-butter',
#    'light-margarines',
#    'liquid-margarines',
#    'salted-margarines',
#    'unsalted-margarines',
#    'shea-butter',
#    'argan-oils',
#    'borage-seed-oils',
#    'amaranth-oils',
#    'corn-oils',
#    'linseed-oils',
#    'rice-bran-oils',
#    'sesame-oils',
#    'wheat-germ-oils',
#    'cottonseed-oils',
#    'avocado-oils',
#    'refined-coco-oils',
#    'virgin-coco-oils',
#    'grape-seed-oils',
#    'watermelon-seed-oils',
#    'hemp-oils',
#    'soybean-oils',
#    'mustard-oils',
#    'almond-oils',
#    'hazelnut-oils',
#    'macadamia-oils',
#    'peanut-oils',
#    'pecan-oils',
#    'pine-nut-oils',
#    'pistachio-oils',
#    'walnut-oils',
#    'refined-olive-oils',
#    'virgin-olive-oils',
#    'palm-oils',
#    'poppyseed-oils',
#    'pumpkin-seed-oils',
#    'rapeseed-oils',
#    'safflower-oils',
#    'nonrefined-sunflower-oils',
#    'refined-deodorized-sunflower-oils',
#    'tea-seed-oils'],
#   'vectorized_representation': array([[ 0.06655197, -0.121017  , -0.01751328, ...,  0.14263026,
#           -0.08179612,  0.07841115],
#          [ 0.03914701, -0.22515778, -0.07342684, ...,  0.05060444,
#           -0.20894401,  0.04136843],
#          [ 0.00449361, -0.10489757, -0.01326862, ...,  0.10254609,
#           -0.20607053, -0.10112188],
#          ...,
#          [-0.0652265 ,  0.08388969,  0.03178098, ...,  0.00690491,
#           -0.06360808, -0.01604903],
#          [-0.01567535,  0.04020074, -0.01521507, ...,  0.05433523,
#           -0.08950766, -0.00209042],
#          [ 0.043823  , -0.32133675, -0.09922929, ...,  0.0758001 ,
#           -0.06465267,  0.01825802]], dtype=float32)},
#  113: {'ingredient_names': ['canned-champignon-mushrooms',
#    'canned-chanterelles',
#    'canned-hygrophorus-latitabundus',
#    'canned-king-trumpet-mushrooms',
#    'canned-nameko-mushrooms',
#    'canned-oyster-mushrooms',
#    'canned-paddy-straw-mushrooms',
#    'canned-porcini-mushrooms',
#    'canned-red-pine-mushrooms',
#    'canned-shiitake-mushrooms',
#    'canned-truffles',
#    'dried-horn-of-plenty-mushrooms',
#    'dried-jew-s-ear-mushrooms',
#    'dried-oyster-mushrooms',
#    'dried-porcini-mushrooms',
#    'dried-scotch-bonnet-mushrooms',
#    'dried-shiitake-mushrooms',
#    'bloody-milk-caps',
#    'champignon-mushrooms',
#    'chanterelles',
#    'horn-of-plenty-mushrooms',
#    'hygrophorus-latitabundus',
#    'jew-s-ear-mushrooms',
#    'king-trumpet-mushrooms',
#    'mixed-mushrooms',
#    'morel',
#    'nameko-mushrooms',
#    'oyster-mushrooms',
#    'paddy-straw-mushrooms',
#    'porcini-mushrooms',
#    'red-pine-mushrooms',
#    'scotch-bonnet-mushrooms',
#    'shiitake-mushrooms',
#    'bagnoli-truffles',
#    'black-truffles',
#    'burgundy-truffles',
#    'chinese-black-truffles',
#    'summer-truffles',
#    'white-truffles',
#    'whitish-truffles',
#    'winter-truffles',
#    'frozen-champignon-mushrooms',
#    'frozen-chanterelle-mushrooms',
#    'frozen-oyster-mushrooms',
#    'frozen-porcini-mushrooms',
#    'chestnut-mushrooms'],
#   'vectorized_representation': array([[ 0.00323673,  0.14430995, -0.00583127, ..., -0.04096491,
#           -0.02086003,  0.02738244],
#          [ 0.01294588,  0.06246963, -0.05160623, ..., -0.07826723,
#            0.05542314, -0.01243462],
#          [ 0.07101376, -0.0369467 ,  0.02558315, ..., -0.04911836,
#            0.05769606,  0.01233066],
#          ...,
#          [ 0.04454844,  0.12162801, -0.11893698, ..., -0.14395101,
#            0.02678234,  0.00805292],
#          [ 0.00050615,  0.04230841, -0.09583252, ..., -0.04433156,
#           -0.0403757 ,  0.00278908],
#          [-0.06721266,  0.04428912,  0.00865404, ...,  0.04415995,
#            0.15061322,  0.04402829]], dtype=float32)},
#  144: {'ingredient_names': ['braised-hams',
#    'diced-ham',
#    'serrano-hams',
#    'white-hams',
#    'pike-rillettes',
#    'tuna-rillettes',
#    'alsatian-liver-sausages',
#    'liver-sausages-from-ariege',
#    'lorrain-sausages',
#    'lyon-sausage',
#    'molene-sausage',
#    'montbeliard-sausages',
#    'morteau-sausages',
#    'toulouse-sausages',
#    'thuringian-sausages',
#    'pickled-sausages',
#    'chicken-sausages',
#    'turkey-sausages',
#    'smoked-sausages',
#    'bison-terrines',
#    'blood-sausage-terrines',
#    'boar-terrines',
#    'chicken-terrines',
#    'country-terrines',
#    'duck-terrines',
#    'pheasant-terrines',
#    'rabbit-terrines',
#    'salmon-terrines',
#    'trout-terrines'],
#   'vectorized_representation': array([[-0.10168482, -0.25699952, -0.02141984, ...,  0.12400223,
#           -0.09858856, -0.0972141 ],
#          [-0.10822242, -0.02124516, -0.06094239, ...,  0.07989453,
#           -0.07685279, -0.14049049],
#          [-0.18504114,  0.13625686,  0.01652881, ...,  0.10719012,
#            0.02615828, -0.06175957],
#          ...,
#          [ 0.00920382,  0.00157629, -0.08504903, ...,  0.06877645,
#            0.15803756, -0.03863501],
#          [-0.07516254, -0.00458518, -0.11588532, ...,  0.09763179,
#            0.04795231, -0.01459628],
#          [-0.15879661, -0.03563072, -0.11389127, ...,  0.04901956,
#            0.11514951, -0.01698951]], dtype=float32)},
#  148: {'ingredient_names': ['basil',
#    'bay',
#    'chives',
#    'coriander-leaves',
#    'dill',
#    'fennel-leaves',
#    'fenugreek-leaves',
#    'garden-chervil-leaves',
#    'hyssop',
#    'lemon-grass',
#    'lemon-verbena',
#    'marjoram',
#    'mint',
#    'oregano',
#    'parsley',
#    'rosemary',
#    'tarragon',
#    'thyme',
#    'frozen-basil',
#    'frozen-chives',
#    'frozen-dill',
#    'frozen-mint',
#    'frozen-parsley',
#    'ground-dried-basil',
#    'ground-dried-bay',
#    'ground-dried-chives',
#    'ground-dried-coriander-leaves',
#    'ground-dried-dill',
#    'ground-dried-fenugreek-leaves',
#    'ground-dried-lemon-verbena',
#    'ground-dried-mint',
#    'ground-dried-oregano',
#    'ground-dried-parsley',
#    'ground-dried-rosemary',
#    'ground-dried-sage',
#    'ground-dried-tarragon',
#    'ground-dried-thyme',
#    'anise',
#    'cardamom',
#    'cinnamon-powder',
#    'cinnamon-sticks',
#    'ground-cloves',
#    'whole-cloves',
#    'coriander-seeds',
#    'ground-cumin-seeds',
#    'whole-cumin-seeds',
#    'garden-chervil-seeds',
#    'fresh-ginger',
#    'gari',
#    'ginger-powder',
#    'mace',
#    'nutmeg',
#    'paprika',
#    'cayenne-peppers',
#    'gray-peppers',
#    'black-peppercorns',
#    'green-peppercorns',
#    'white-peppercorns',
#    'pink-peppers',
#    'powdered-saffron',
#    'saffron-threads',
#    'star-anise',
#    'turmeric-powder',
#    'fresh-turmeric',
#    'vanilla-extract',
#    'vanilla-pods',
#    'vanilla-powder',
#    'sage'],
#   'vectorized_representation': array([[-0.1210253 ,  0.05502281, -0.00569629, ...,  0.04243582,
#            0.01181373,  0.01831058],
#          [-0.19709909, -0.00366672, -0.03120048, ..., -0.01942907,
#            0.08251911, -0.07131594],
#          [-0.18629923, -0.27542174, -0.03406437, ...,  0.0840756 ,
#            0.0376948 , -0.12671347],
#          ...,
#          [ 0.09358637, -0.15753114, -0.09121735, ...,  0.17358835,
#           -0.09214003,  0.08130286],
#          [ 0.03028488, -0.16597418, -0.02900309, ...,  0.11558127,
#           -0.10006182,  0.12256181],
#          [-0.09460571,  0.216969  ,  0.00179128, ...,  0.06707703,
#            0.12503368, -0.05270675]], dtype=float32)}}

# %%
### Match ingredients with taxonomy

INIT_TIME = time.time()

# df_matched_ingredients = match_ingredients(df_ingredients.sample(n = 50, random_state = RANDOM_SEED), model, dict_vectorised_taxonomy)
df_matched_ingredients = match_ingredients(df_ingredients, model, dict_vectorised_taxonomy)

FINAL_TIME = time.time() - INIT_TIME

print(f'Time to compute function: {FINAL_TIME:.2f} seconds')

# Export results
filename = f'{CSV_PATH}{_get_key()}matched_ingredients.csv'
df_matched_ingredients.to_csv(filename, index = False)
# Out:
# Time to compute function: 1961.38 seconds

# %%
### Plot ingredient histogram

df_matched_ingredients_plot = df_matched_ingredients[['matched_score']]

# Transform dataframe to format plot
df_matched_ingredients_plot.loc[df_matched_ingredients_plot['matched_score'] < 0, 'matched_score'] = 0.1
df_matched_ingredients_plot.loc[df_matched_ingredients_plot['matched_score'] > 1, 'matched_score'] = 1
df_matched_ingredients_plot['rounded_score'] = np.ceil(df_matched_ingredients_plot['matched_score'] * 10) / 10

# Group data for plot
df_matched_ingredients_plot = pd.DataFrame(df_matched_ingredients_plot['rounded_score'].value_counts())
df_matched_ingredients_plot.reset_index(inplace = True)
df_matched_ingredients_plot.rename(columns = {'index': 'score', 'rounded_score': 'count'}, inplace = True)
df_matched_ingredients_plot.sort_values(by = 'score', inplace = True)
df_matched_ingredients_plot.reset_index(drop = True, inplace = True)
df_matched_ingredients_plot['distribution'] = df_matched_ingredients_plot['count'] / sum(df_matched_ingredients_plot['count'])
df_matched_ingredients_plot['group'] = 'poor'
df_matched_ingredients_plot.loc[df_matched_ingredients_plot['score'] > 0.6, 'group'] = 'medium'
df_matched_ingredients_plot.loc[df_matched_ingredients_plot['score'] > 0.8, 'group'] = 'high'
df_matched_ingredients_plot.reset_index(inplace = True)

# Save data
filename = f'{CSV_PATH}{_get_key()}plot_histogram.csv'
df_matched_ingredients_plot.to_csv(filename, index = False)

# Compute distribution per group
df_MIP_plot = df_matched_ingredients_plot[['group', 'distribution']].groupby(['group'], as_index = False).sum()

print('Distribution of groups:')
print(df_MIP_plot)
print('')

# Compute axes and colours
COLOURS = {'poor': '#ff7276',
          'medium': '#ffac1c',
          'high': '#008000'}

df_axis = df_matched_ingredients_plot[['score']].rename(columns = {'score': 'upper_limit'})
df_axis['lower_limit'] = df_axis['upper_limit'] - 0.1
df_axis['lower_limit'] = np.round(df_axis['lower_limit'], 1)
df_axis['upper_limit'] = np.round(df_axis['upper_limit'], 1)
df_axis['tag'] = '(' + df_axis['lower_limit'].apply(str) + '-' + df_axis['upper_limit'].apply(str) + ']'
df_axis.reset_index(inplace = True)

# Plot histogram
fig = plt.figure(1, (13, 7))
ax = fig.add_subplot(1, 1, 1)

for key in COLOURS.keys():
    DF_PLOT = df_matched_ingredients_plot[df_matched_ingredients_plot['group'] == key]
    
    ax.bar(x = DF_PLOT['index'],
           height = DF_PLOT['distribution'] * 100,
           width = 0.95,
           label = key,
           color = COLOURS[key])
# Set x ticks
ax.set_xticks(df_axis['index'])
ax.set_xticklabels(df_axis['tag'])

# Set percentage axis
yticks = mticker.FormatStrFormatter('%.0f%%')
ax.yaxis.set_major_formatter(yticks)

# Set labels
ax.set_xlabel('Matching score', fontsize = PLOT_SETUP['label'])
ax.set_ylabel('Distribution', fontsize = PLOT_SETUP['label'])

# Set title
ax.set_title('Distribution of matching score on sample', fontsize = PLOT_SETUP['title'])

# Set tick size
ax.tick_params(axis = 'both', which = 'major', labelsize = PLOT_SETUP['tick'])

# Set legend
ax.legend(loc = 'best', fontsize = PLOT_SETUP['legend'], title = 'Match')

plt.show()
# Out:
# Distribution of groups:
#     group  distribution
# 0    high      0.108815
# 1  medium      0.485978
# 2    poor      0.405207

# %%
df_matched_ingredients.sample(20, random_state = RANDOM_SEED).\
    sort_values(by = ['category_id', 'matched_score'], ascending = [True, False])#.\
#     to_excel(EXCEL_PATH + 'matching_sample.xlsx')
# Out:
#       ingredient_id category_id  \
# 1907         861106         101
# 3178        1033966         101
# 15135        976087         102
# 7483         716165         102
# 20167       1096587         102
# 26676        715603         103
# 39502       1245142         103
# 28973        807673         103
# 36914       1145422         103
# 31114        935248         103
# 40453        681335         107
# 42240        772422         107
# 43077        863357         107
# 40007        658689         107
# 52738       1006263         108
# 55511        680682         109
# 56468        937476         109
# 56884       1022745         109
# 65994       1064007         148
# 63064        662036         148
#
#                                          ingredient_name         date_created  \
# 1907   Pier 7 MSC Extra Large Cod Fillets Skinless & ...  2021-09-03 07:38:00
# 3178   MSC Large Haddock Fillets Skinless & Boneless ...  2021-10-12 13:43:20
# 15135             Farmstead Pork Sausage Chipolata 16s -  2021-09-29 13:05:13
# 7483                          Farmstead Puck Burger 113g  2021-05-20 15:08:51
# 20167              Farmstead Whole Chicken Red Tractor -  2021-10-29 16:14:27
# 26676  (Prep 2pm) - 3mm SLICED CARROTS x 2.5Kg Pack O...  2021-05-20 14:37:44
# 39502                      2.5kg Sliced Piquillo Peppers  2022-05-05 11:03:17
# 28973                      BB - BABY HERITAGE CARROT  D4  2021-08-27 21:53:03
# 36914                        Leek Baby Legumes   400g Sp  2022-02-02 17:56:01
# 31114                  Lamb Weston Luxury Homestyle Mash  2021-09-15 11:55:28
# 40453  Ubley Thick 'n' Creamy Fruited Yoghurt Mixed C...  2021-04-22 16:25:12
# 42240                Alpro Organic Unsweetened Soya Milk  2021-08-17 11:38:20
# 43077                           Argyll Eggs Medium Loose  2021-09-03 07:45:24
# 40007                     Knorr Garde dOr Bechamel Sauce  2021-03-01 12:39:57
# 52738                                 Toffee Apple PO D4  2021-10-07 16:14:42
# 55511                                Wing's Udon Noodles  2021-04-22 16:22:34
# 56468                      S&B Easy Cook Long Grain Rice  2021-09-15 12:02:30
# 56884                        Lion No.1 Chop Suey Noodles  2021-10-08 11:35:37
# 65994                Everyday Favourites Cinnamon Sticks  2021-10-27 16:45:00
# 63064                                        Cumin Seeds  2021-03-02 17:03:31
#
#             matched_ingredient matched_score
# 1907               cod-fillets      0.765077
# 3178               cod-fillets        0.6783
# 15135                pork-ribs      0.627039
# 7483               ground-beef      0.573611
# 20167            chicken-wings       0.43053
# 26676           canned-carrots       0.72057
# 39502           canned-peppers        0.6881
# 28973                  carrots      0.671882
# 36914                    leeks       0.61309
# 31114             fennel-bulbs      0.319801
# 40453    fruit-stirred-yogurts      0.683065
# 42240        lactose-free-milk      0.678616
# 43077               fresh-eggs      0.675675
# 40007       appenzeller-cheese      0.578177
# 52738  golden-delicious-apples      0.491602
# 55511              egg-noodles      0.807303
# 56468    long-grain-white-rice      0.779957
# 56884              egg-noodles      0.638451
# 65994          cinnamon-sticks      0.905039
# 63064       ground-cumin-seeds      0.890049
